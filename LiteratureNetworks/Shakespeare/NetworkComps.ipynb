# %%
# %matplotlib inline 
# %load_ext autoreload
import networkx as nx
# %autoreload 2
from utils import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
nodes=25
p=0.08
G,sstt=create_conn_random_graph(nodes,p)

# %%
pos=draw_network(G,sstt,withLabels=True)

# %%
print G.edges()
# Out:
# [(0, 24), (0, 9), (0, 6), (1, 2), (2, 19), (2, 12), (2, 13), (3, 24), (3, 19), (4, 10), (5, 10), (5, 20), (6, 20), (7, 8), (7, 19), (7, 22), (9, 17), (10, 19), (10, 22), (11, 23), (12, 18), (12, 22), (14, 22), (15, 21), (16, 17), (16, 20), (17, 21), (22, 23)]

# %%
draw_centralities(G,'degree_centrality',pos,withLabels=True)
# Out:
# Node 22 has degree centrality = 0.2083
# Node 2 has degree centrality = 0.1667
# Node 10 has degree centrality = 0.1667
# Node 19 has degree centrality = 0.1667
# Node 0 has degree centrality = 0.1250
# Node 7 has degree centrality = 0.1250
# Node 12 has degree centrality = 0.1250
# Node 17 has degree centrality = 0.1250
# Node 20 has degree centrality = 0.1250
# Node 3 has degree centrality = 0.0833
# Node 5 has degree centrality = 0.0833
# Node 6 has degree centrality = 0.0833
# Node 9 has degree centrality = 0.0833
# Node 16 has degree centrality = 0.0833
# Node 21 has degree centrality = 0.0833
# Node 23 has degree centrality = 0.0833
# Node 24 has degree centrality = 0.0833
# Node 1 has degree centrality = 0.0417
# Node 4 has degree centrality = 0.0417
# Node 8 has degree centrality = 0.0417
# Node 11 has degree centrality = 0.0417
# Node 13 has degree centrality = 0.0417
# Node 14 has degree centrality = 0.0417
# Node 15 has degree centrality = 0.0417
# Node 18 has degree centrality = 0.0417

# %%
draw_centralities(G,'closeness_centrality',pos,withLabels=True)
# Out:
# Node 10 has closeness centrality = 0.3636
# Node 19 has closeness centrality = 0.3478
# Node 22 has closeness centrality = 0.3333
# Node 5 has closeness centrality = 0.3288
# Node 3 has closeness centrality = 0.3077
# Node 2 has closeness centrality = 0.3000
# Node 7 has closeness centrality = 0.3000
# Node 20 has closeness centrality = 0.3000
# Node 12 has closeness centrality = 0.2927
# Node 24 has closeness centrality = 0.2824
# Node 4 has closeness centrality = 0.2697
# Node 0 has closeness centrality = 0.2609
# Node 23 has closeness centrality = 0.2581
# Node 6 has closeness centrality = 0.2526
# Node 14 has closeness centrality = 0.2526
# Node 16 has closeness centrality = 0.2526
# Node 1 has closeness centrality = 0.2330
# Node 8 has closeness centrality = 0.2330
# Node 13 has closeness centrality = 0.2330
# Node 18 has closeness centrality = 0.2286
# Node 17 has closeness centrality = 0.2264
# Node 9 has closeness centrality = 0.2243
# Node 11 has closeness centrality = 0.2069
# Node 21 has closeness centrality = 0.1890
# Node 15 has closeness centrality = 0.1600

# %%
draw_centralities(G,'betweenness_centrality',pos,withLabels=True)
# Out:
# Node 10 has betweenness centrality = 0.3998
# Node 22 has betweenness centrality = 0.3430
# Node 19 has betweenness centrality = 0.3333
# Node 5 has betweenness centrality = 0.2893
# Node 20 has betweenness centrality = 0.2778
# Node 2 has betweenness centrality = 0.1993
# Node 17 has betweenness centrality = 0.1775
# Node 3 has betweenness centrality = 0.1721
# Node 16 has betweenness centrality = 0.1600
# Node 24 has betweenness centrality = 0.1455
# Node 0 has betweenness centrality = 0.1455
# Node 12 has betweenness centrality = 0.1268
# Node 7 has betweenness centrality = 0.1135
# Node 21 has betweenness centrality = 0.0833
# Node 23 has betweenness centrality = 0.0833
# Node 9 has betweenness centrality = 0.0719
# Node 6 has betweenness centrality = 0.0374
# Node 1 has betweenness centrality = 0.0000
# Node 4 has betweenness centrality = 0.0000
# Node 8 has betweenness centrality = 0.0000
# Node 11 has betweenness centrality = 0.0000
# Node 13 has betweenness centrality = 0.0000
# Node 14 has betweenness centrality = 0.0000
# Node 15 has betweenness centrality = 0.0000
# Node 18 has betweenness centrality = 0.0000

# %%
draw_centralities(G,'eigenvector_centrality',pos,withLabels=True)
# Out:
# Node 22 has eigenvector centrality = 0.4555
# Node 19 has eigenvector centrality = 0.4031
# Node 10 has eigenvector centrality = 0.3908
# Node 7 has eigenvector centrality = 0.3294
# Node 2 has eigenvector centrality = 0.3068
# Node 12 has eigenvector centrality = 0.2924
# Node 23 has eigenvector centrality = 0.1747
# Node 3 has eigenvector centrality = 0.1607
# Node 5 has eigenvector centrality = 0.1602
# Node 14 has eigenvector centrality = 0.1546
# Node 4 has eigenvector centrality = 0.1327
# Node 8 has eigenvector centrality = 0.1118
# Node 1 has eigenvector centrality = 0.1041
# Node 13 has eigenvector centrality = 0.1041
# Node 18 has eigenvector centrality = 0.0993
# Node 20 has eigenvector centrality = 0.0811
# Node 24 has eigenvector centrality = 0.0704
# Node 11 has eigenvector centrality = 0.0593
# Node 0 has eigenvector centrality = 0.0466
# Node 6 has eigenvector centrality = 0.0433
# Node 16 has eigenvector centrality = 0.0353
# Node 9 has eigenvector centrality = 0.0236
# Node 17 has eigenvector centrality = 0.0230
# Node 21 has eigenvector centrality = 0.0088
# Node 15 has eigenvector centrality = 0.0030

# %%
draw_centralities(G,'katz_centrality',pos,withLabels=True)
# Out:
# Node 17 has Katz centrality = 0.4760
# Node 21 has Katz centrality = 0.3726
# Node 12 has Katz centrality = 0.3323
# Node 2 has Katz centrality = 0.3141
# Node 16 has Katz centrality = 0.2880
# Node 15 has Katz centrality = 0.1926
# Node 9 has Katz centrality = 0.1781
# Node 18 has Katz centrality = 0.1681
# Node 1 has Katz centrality = 0.1571
# Node 13 has Katz centrality = 0.1571
# Node 22 has Katz centrality = 0.1201
# Node 20 has Katz centrality = 0.0534
# Node 14 has Katz centrality = 0.0391
# Node 23 has Katz centrality = 0.0293
# Node 11 has Katz centrality = -0.0161
# Node 7 has Katz centrality = -0.0421
# Node 8 has Katz centrality = -0.0595
# Node 5 has Katz centrality = -0.0654
# Node 19 has Katz centrality = -0.0740
# Node 6 has Katz centrality = -0.0789
# Node 4 has Katz centrality = -0.0979
# Node 10 has Katz centrality = -0.1052
# Node 0 has Katz centrality = -0.1274
# Node 3 has Katz centrality = -0.2326
# Node 24 has Katz centrality = -0.2528
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:717: RuntimeWarning: invalid value encountered in sqrt
#   for x in self._sizes]

# %%
draw_centralities(G,'page_rank',pos,withLabels=True)
# Out:
# Node 22 has pagerank = 0.0832
# Node 2 has pagerank = 0.0700
# Node 10 has pagerank = 0.0650
# Node 19 has pagerank = 0.0638
# Node 17 has pagerank = 0.0537
# Node 12 has pagerank = 0.0529
# Node 7 has pagerank = 0.0511
# Node 0 has pagerank = 0.0507
# Node 20 has pagerank = 0.0502
# Node 21 has pagerank = 0.0412
# Node 23 has pagerank = 0.0395
# Node 9 has pagerank = 0.0356
# Node 16 has pagerank = 0.0354
# Node 24 has pagerank = 0.0350
# Node 6 has pagerank = 0.0346
# Node 3 has pagerank = 0.0344
# Node 5 has pagerank = 0.0341
# Node 15 has pagerank = 0.0235
# Node 11 has pagerank = 0.0228
# Node 18 has pagerank = 0.0210
# Node 1 has pagerank = 0.0209
# Node 13 has pagerank = 0.0209
# Node 8 has pagerank = 0.0205
# Node 14 has pagerank = 0.0201
# Node 4 has pagerank = 0.0198

# %%
draw_centralities_subplots(G,pos,withLabels=True)

# %%
from chAs import draw_comms_random,modul_arity
import community as comm

part=comm.best_partition(G) 
print 'Number of communities =', max(part.values())+1
print 'Community partition:'
parLis=[]
partdi={}
for i,k in part.items():
    if k not in partdi:
        partdi[k]=[i]
    else:
        partdi[k].append(i)
for i,k in partdi.items():
    parLis.append(k)
print parLis
print 'Community modularity =', "%.4f" % comm.modularity(part,G)

d=0.8 
dd=0.8
c=1.2
cc=1.4
alpha=0.2
ealpha=.2
vcc={}
sstt="The %s Communities" %(max(part.values())+1)

draw_comms_random(G,G.nodes(),[],[],[] ,part,part,d,dd,c,cc,alpha,ealpha,sstt)
# Out:
# Number of communities = 5
# Community partition:
# [[0, 5, 6, 20, 24], [1, 2, 12, 13, 18], [3, 7, 8, 19], [4, 10, 11, 14, 22, 23], [9, 15, 16, 17, 21]]
# Community modularity = 0.5102
