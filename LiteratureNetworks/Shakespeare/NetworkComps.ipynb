# %%
# %matplotlib inline 
# %load_ext autoreload
import networkx as nx
# %autoreload 2
from utils import *

# %%
nodes=20
p=0.08
G,sstt=create_conn_random_graph(nodes,p)

# %%
pos=draw_network(G,sstt,withLabels=True)

# %%
draw_centralities(G,'degree_centrality',pos,withLabels=True)
# Out:
# Node 2 has degree centrality = 0.2105
# Node 8 has degree centrality = 0.2105
# Node 10 has degree centrality = 0.2105
# Node 15 has degree centrality = 0.2105
# Node 16 has degree centrality = 0.1579
# Node 19 has degree centrality = 0.1579
# Node 0 has degree centrality = 0.1053
# Node 1 has degree centrality = 0.1053
# Node 5 has degree centrality = 0.1053
# Node 6 has degree centrality = 0.1053
# Node 13 has degree centrality = 0.1053
# Node 14 has degree centrality = 0.1053
# Node 3 has degree centrality = 0.0526
# Node 4 has degree centrality = 0.0526
# Node 7 has degree centrality = 0.0526
# Node 9 has degree centrality = 0.0526
# Node 11 has degree centrality = 0.0526
# Node 12 has degree centrality = 0.0526
# Node 17 has degree centrality = 0.0526
# Node 18 has degree centrality = 0.0526

# %%
draw_centralities(G,'closeness_centrality',pos,withLabels=True)
# Out:
# Node 10 has closeness centrality = 0.4222
# Node 15 has closeness centrality = 0.3878
# Node 8 has closeness centrality = 0.3800
# Node 16 has closeness centrality = 0.3800
# Node 2 has closeness centrality = 0.3519
# Node 1 has closeness centrality = 0.3167
# Node 5 has closeness centrality = 0.3167
# Node 0 has closeness centrality = 0.3115
# Node 6 has closeness centrality = 0.3065
# Node 7 has closeness centrality = 0.2836
# Node 9 has closeness centrality = 0.2836
# Node 17 has closeness centrality = 0.2794
# Node 13 has closeness centrality = 0.2714
# Node 14 has closeness centrality = 0.2714
# Node 19 has closeness centrality = 0.2500
# Node 12 has closeness centrality = 0.2405
# Node 11 has closeness centrality = 0.2159
# Node 18 has closeness centrality = 0.2159
# Node 3 has closeness centrality = 0.2021
# Node 4 has closeness centrality = 0.2021

# %%
draw_centralities(G,'betweenness_centrality',pos,withLabels=True)
# Out:
# Node 10 has betweenness centrality = 0.5497
# Node 8 has betweenness centrality = 0.4678
# Node 2 has betweenness centrality = 0.3918
# Node 15 has betweenness centrality = 0.3363
# Node 6 has betweenness centrality = 0.2807
# Node 16 has betweenness centrality = 0.2251
# Node 19 has betweenness centrality = 0.2047
# Node 0 has betweenness centrality = 0.1053
# Node 13 has betweenness centrality = 0.1053
# Node 14 has betweenness centrality = 0.1053
# Node 1 has betweenness centrality = 0.0351
# Node 5 has betweenness centrality = 0.0351
# Node 3 has betweenness centrality = 0.0000
# Node 4 has betweenness centrality = 0.0000
# Node 7 has betweenness centrality = 0.0000
# Node 9 has betweenness centrality = 0.0000
# Node 11 has betweenness centrality = 0.0000
# Node 12 has betweenness centrality = 0.0000
# Node 17 has betweenness centrality = 0.0000
# Node 18 has betweenness centrality = 0.0000

# %%
draw_centralities(G,'eigenvector_centrality',pos,withLabels=True)
# Out:
# Node 10 has eigenvector centrality = 0.4537
# Node 15 has eigenvector centrality = 0.4024
# Node 2 has eigenvector centrality = 0.3885
# Node 16 has eigenvector centrality = 0.3704
# Node 8 has eigenvector centrality = 0.3150
# Node 1 has eigenvector centrality = 0.1971
# Node 0 has eigenvector centrality = 0.1852
# Node 5 has eigenvector centrality = 0.1825
# Node 13 has eigenvector centrality = 0.1586
# Node 14 has eigenvector centrality = 0.1586
# Node 7 has eigenvector centrality = 0.1434
# Node 9 has eigenvector centrality = 0.1434
# Node 6 has eigenvector centrality = 0.1353
# Node 17 has eigenvector centrality = 0.1123
# Node 12 has eigenvector centrality = 0.0660
# Node 19 has eigenvector centrality = 0.0646
# Node 11 has eigenvector centrality = 0.0565
# Node 18 has eigenvector centrality = 0.0565
# Node 3 has eigenvector centrality = 0.0230
# Node 4 has eigenvector centrality = 0.0230

# %%
draw_centralities(G,'page_rank',pos,withLabels=True)
# Out:
# Node 15 has pagerank = 0.0885
# Node 2 has pagerank = 0.0871
# Node 8 has pagerank = 0.0868
# Node 10 has pagerank = 0.0835
# Node 19 has pagerank = 0.0786
# Node 16 has pagerank = 0.0626
# Node 13 has pagerank = 0.0507
# Node 14 has pagerank = 0.0507
# Node 0 has pagerank = 0.0495
# Node 6 has pagerank = 0.0482
# Node 5 has pagerank = 0.0448
# Node 1 has pagerank = 0.0442
# Node 3 has pagerank = 0.0298
# Node 4 has pagerank = 0.0298
# Node 11 has pagerank = 0.0291
# Node 18 has pagerank = 0.0291
# Node 12 has pagerank = 0.0285
# Node 7 has pagerank = 0.0263
# Node 9 has pagerank = 0.0263
# Node 17 has pagerank = 0.0259

# %%
draw_centralities_subplots(G,pos,withLabels=True)

# %%
from chAs import draw_comms_random,modul_arity
import community as comm

part=comm.best_partition(G) 
print 'Number of communities =', max(part.values())+1
print 'Community partition:'
parLis=[]
partdi={}
for i,k in part.items():
    if k not in partdi:
        partdi[k]=[i]
    else:
        partdi[k].append(i)
for i,k in partdi.items():
    parLis.append(k)
print parLis
print 'Community modularity =', "%.4f" % comm.modularity(part,G)

d=0.8 
dd=0.8
c=1.2
cc=1.4
alpha=0.2
ealpha=.2
vcc={}
sstt="The %s Communities" %(max(part.values())+1)

draw_comms_random(G,G.nodes(),[],[],[] ,part,part,d,dd,c,cc,alpha,ealpha,sstt)
# Out:
# Number of communities = 5
# Community partition:
# [[0, 10, 12, 16], [1, 5, 6, 8, 17], [2, 11, 13, 14, 18], [3, 4, 19], [7, 9, 15]]
# Community modularity = 0.4977
