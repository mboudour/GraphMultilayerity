# %%
# %matplotlib inline 
# %load_ext autoreload
import networkx as nx
# %autoreload 2
from utils import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
nodes=20
p=0.08
G,sstt=create_conn_random_graph(nodes,p)

# %%
pos=draw_network(G,sstt,withLabels=True)

# %%
draw_centralities(G,'degree_centrality',pos,withLabels=True)
# Out:
# Node 0 has degree centrality = 0.2105
# Node 5 has degree centrality = 0.2105
# Node 17 has degree centrality = 0.2105
# Node 3 has degree centrality = 0.1579
# Node 4 has degree centrality = 0.1579
# Node 8 has degree centrality = 0.1579
# Node 9 has degree centrality = 0.1579
# Node 10 has degree centrality = 0.1579
# Node 11 has degree centrality = 0.1579
# Node 12 has degree centrality = 0.1579
# Node 13 has degree centrality = 0.1579
# Node 15 has degree centrality = 0.1579
# Node 18 has degree centrality = 0.1579
# Node 1 has degree centrality = 0.1053
# Node 6 has degree centrality = 0.1053
# Node 14 has degree centrality = 0.1053
# Node 2 has degree centrality = 0.0526
# Node 7 has degree centrality = 0.0526
# Node 16 has degree centrality = 0.0526
# Node 19 has degree centrality = 0.0526

# %%
draw_centralities(G,'closeness_centrality',pos,withLabels=True)
# Out:
# Node 8 has closeness centrality = 0.3455
# Node 9 has closeness centrality = 0.3455
# Node 3 has closeness centrality = 0.3220
# Node 15 has closeness centrality = 0.3220
# Node 10 has closeness centrality = 0.3065
# Node 13 has closeness centrality = 0.2794
# Node 5 has closeness centrality = 0.2754
# Node 12 has closeness centrality = 0.2714
# Node 1 has closeness centrality = 0.2676
# Node 17 has closeness centrality = 0.2405
# Node 0 has closeness centrality = 0.2375
# Node 19 has closeness centrality = 0.2375
# Node 4 has closeness centrality = 0.2346
# Node 18 has closeness centrality = 0.2317
# Node 7 has closeness centrality = 0.2209
# Node 14 has closeness centrality = 0.2209
# Node 2 has closeness centrality = 0.2159
# Node 11 has closeness centrality = 0.2021
# Node 6 has closeness centrality = 0.1979
# Node 16 has closeness centrality = 0.1939

# %%
draw_centralities(G,'betweenness_centrality',pos,withLabels=True)
# Out:
# Node 8 has betweenness centrality = 0.5146
# Node 9 has betweenness centrality = 0.5146
# Node 15 has betweenness centrality = 0.5029
# Node 3 has betweenness centrality = 0.5010
# Node 13 has betweenness centrality = 0.2953
# Node 5 has betweenness centrality = 0.2417
# Node 12 has betweenness centrality = 0.1813
# Node 17 has betweenness centrality = 0.1550
# Node 0 has betweenness centrality = 0.1306
# Node 1 has betweenness centrality = 0.1140
# Node 10 has betweenness centrality = 0.1053
# Node 4 has betweenness centrality = 0.0556
# Node 18 has betweenness centrality = 0.0097
# Node 11 has betweenness centrality = 0.0058
# Node 2 has betweenness centrality = 0.0000
# Node 6 has betweenness centrality = 0.0000
# Node 7 has betweenness centrality = 0.0000
# Node 14 has betweenness centrality = 0.0000
# Node 16 has betweenness centrality = 0.0000
# Node 19 has betweenness centrality = 0.0000

# %%
draw_centralities(G,'eigenvector_centrality',pos,withLabels=True)
# Out:
# Node 5 has eigenvector centrality = 0.4908
# Node 0 has eigenvector centrality = 0.4442
# Node 18 has eigenvector centrality = 0.4108
# Node 3 has eigenvector centrality = 0.3207
# Node 14 has eigenvector centrality = 0.2999
# Node 12 has eigenvector centrality = 0.2861
# Node 8 has eigenvector centrality = 0.1873
# Node 16 has eigenvector centrality = 0.1478
# Node 9 has eigenvector centrality = 0.1255
# Node 10 has eigenvector centrality = 0.1170
# Node 2 has eigenvector centrality = 0.0952
# Node 15 has eigenvector centrality = 0.0729
# Node 17 has eigenvector centrality = 0.0653
# Node 4 has eigenvector centrality = 0.0531
# Node 11 has eigenvector centrality = 0.0524
# Node 13 has eigenvector centrality = 0.0517
# Node 1 has eigenvector centrality = 0.0419
# Node 6 has eigenvector centrality = 0.0392
# Node 19 has eigenvector centrality = 0.0389
# Node 7 has eigenvector centrality = 0.0172

# %%
draw_centralities(G,'page_rank',pos,withLabels=True)
# Out:
# Node 0 has pagerank = 0.0749
# Node 17 has pagerank = 0.0716
# Node 5 has pagerank = 0.0708
# Node 10 has pagerank = 0.0606
# Node 12 has pagerank = 0.0600
# Node 13 has pagerank = 0.0597
# Node 15 has pagerank = 0.0572
# Node 9 has pagerank = 0.0569
# Node 8 has pagerank = 0.0565
# Node 3 has pagerank = 0.0556
# Node 4 has pagerank = 0.0548
# Node 18 has pagerank = 0.0546
# Node 11 has pagerank = 0.0544
# Node 1 has pagerank = 0.0392
# Node 6 has pagerank = 0.0381
# Node 14 has pagerank = 0.0380
# Node 19 has pagerank = 0.0247
# Node 2 has pagerank = 0.0245
# Node 7 has pagerank = 0.0244
# Node 16 has pagerank = 0.0234

# %%
draw_centralities_subplots(G,pos,withLabels=True)

# %%
from chAs import draw_comms_random,modul_arity
import community as comm

part=comm.best_partition(G) 
print 'Number of communities =', max(part.values())+1
print 'Community partition:'
parLis=[]
partdi={}
for i,k in part.items():
    if k not in partdi:
        partdi[k]=[i]
    else:
        partdi[k].append(i)
for i,k in partdi.items():
    parLis.append(k)
print parLis
print 'Community modularity =', "%.4f" % comm.modularity(part,G)

d=0.8 
dd=0.8
c=1.2
cc=1.4
alpha=0.2
ealpha=.2
vcc={}
sstt="The %s Communities" %(max(part.values())+1)

draw_comms_random(G,G.nodes(),[],[],[] ,part,part,d,dd,c,cc,alpha,ealpha,sstt)
# Out:
# Number of communities = 4
# Community partition:
# [[0, 2, 3, 5, 12, 14, 16, 18], [1, 7, 13, 15], [4, 6, 11, 17], [8, 9, 10, 19]]
# Community modularity = 0.5629
